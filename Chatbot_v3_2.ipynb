# %%
import numpy as np
import pandas as pd
import joblib

# %%
df = pd.read_csv('Data_Restaurants.csv', sep = '|')

# %%
# drop unnecessary columns
df = df.drop(['Numero de telephone'], axis=1)

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df['Specialite'] = df['Specialite'].str.lower()
df['Specialite'] = df['Specialite'].str.replace(' ', '_')
df['Region'] = df['Region'].str.lower()
df['Region'] = df['Region'].str.replace(' ', '_')
df['Nom du restaurant'] = df['Nom du restaurant'].str.lower()
df['Nom du restaurant'] = df['Nom du restaurant'].str.replace(' ', '_')

# %%
# remove punctuation
df['Specialite'] = df['Specialite'].str.replace('[^\w\s]','')
df['Region'] = df['Region'].str.replace('[^\w\s]','')
df['Nom du restaurant'] = df['Nom du restaurant'].str.replace('[^\w\s]','')
# Out:
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\629601368.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Specialite'] = df['Specialite'].str.replace('[^\w\s]','')
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\629601368.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Region'] = df['Region'].str.replace('[^\w\s]','')
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\629601368.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Nom du restaurant'] = df['Nom du restaurant'].str.replace('[^\w\s]','')

# %%
#remove stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('french')
df['Specialite'] = df['Specialite'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['Region'] = df['Region'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['Nom du restaurant'] = df['Nom du restaurant'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nostr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# countvectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# linear kernel
from sklearn.metrics.pairwise import linear_kernel

# %%
df_percent = df.sample(frac=0.2)

# %%
df_percent.set_index('Nom du restaurant', inplace=True)
indices = pd.Series(df_percent.index)

# Creating tf-idf matrix
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_percent['Specialite'])

cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
joblib.dump(cosine_similarities, 'recommend_name_restaurant.pkl')
# Out:
# ['recommend_name_restaurant.pkl']

# %%
def recommend_restaurant(name):
    name = name.lower()
    name = name.replace(' ', '_')
    name = name.replace('[^\w\s]','')
    words = name.split()
    # Remove stop words
    filtered_words = [word for word in words if word not in stopwords.words('french')]
    # Join the filtered words back into a sentence
    name = ' '.join(filtered_words)
    indices = pd.Series(df_percent.index)
    cosine_similarities = joblib.load('recommend_name_restaurant.pkl')
    # Create a list to put top restaurants
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    try:
        idx = indices[indices == name].index[0]
    except:
        print('Restaurant non trouvé')
        return None
    
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
# Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    
    # Creating the new data set to show similar restaurants
    df_new = pd.DataFrame(columns=['Specialite', 'Note moyenne', 'Indicateur de prix','Ville','Departement','Region'])
    
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:

        df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
        
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region'], keep=False)
    df_new = df_new.sort_values(by='Note moyenne', ascending=False)
    
    return df_new


recommend_restaurant('mcdonalds')
# Out:
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# C:\Users\nostr\AppData\Local\Temp\ipykernel_7476\588010184.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_new = df_new.append(pd.DataFrame(df_percent[['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region']][df_percent.index == each].sample()))
# TOP 29 RESTAURANTS SIMILAIRE A  mcdonalds AVEC UNE NOTE PROCHE:
#                                         Specialite  Note moyenne  \
# burger_king                      fast_food_burgers           5.0
# mcdonalds            burgers_fast_food_coffee__tea           5.0
# mcdonalds                        fast_food_burgers           4.0
# mc_donalds                             restaurants           4.0
# snack_109_friterie               fast_food_burgers           4.0
# mcdonalds                        fast_food_burgers           4.0
# mcdonalds                        fast_food_burgers           4.0
# upper                            fast_food_burgers           4.0
# mc_donalds                       fast_food_burgers           3.5
# mcdonalds                        burgers_fast_food           3.5
# mcdonalds                        fast_food_burgers           3.5
# mcdonalds                        burgers_fast_food           3.5
# mc_donalds                               fast_food           3.5
# mcdonalds                        fast_food_burgers           3.5
# burger_king                      fast_food_burgers           3.5
# mcdonalds                        fast_food_burgers           3.5
# mcdonalds                                fast_food           3.0
# mcdonalds                        fast_food_burgers           3.0
# mcdonalds                        fast_food_burgers           3.0
# mcdonalds                        fast_food_burgers           3.0
# mcdonalds                        fast_food_burgers           3.0
# mcdonalds                        fast_food_burgers           3.0
# burger_king                      fast_food_burgers           2.5
# mc_donalds                               fast_food           2.0
# mcdonalds                        fast_food_burgers           2.0
# mcdonalds                        fast_food_burgers           2.0
# mcdonalds                        fast_food_burgers           1.5
# mc_donalds          fast_food_american_traditional           1.5
# mc_donalds                             restaurants           1.5
#
#                    Indicateur de prix               Ville Departement  \
# burger_king                   Unknown  Mézières-sur-Seine          78
# mcdonalds                           $              Calais          62
# mcdonalds                     Unknown    Carhaix-Plouguer          29
# mc_donalds                         €€              Elbeuf          76
# snack_109_friterie            Unknown  Bouvigny-Boyeffles          62
# mcdonalds                     Unknown            Massieux           1
# mcdonalds                     Unknown     Ars-sur-Moselle          57
# upper                              €€    Le Taillan-Médoc          33
# mc_donalds                          €              Neyron           1
# mcdonalds                     Unknown      Morainvilliers          78
# mcdonalds                        €€€€           Maraussan          34
# mcdonalds                     Unknown             Juziers          78
# mc_donalds                    Unknown             Mourenx          64
# mcdonalds                           €         La Ferrière          85
# burger_king                         €       Drémil-Lafage          31
# mcdonalds                     Unknown          Escautpont          59
# mcdonalds                          €€               Lèves          28
# mcdonalds                          €€       Lailly-en-Val          45
# mcdonalds                          €€               Ormoy          91
# mcdonalds                     Unknown          Giberville          14
# mcdonalds                          €€             Mennecy          91
# mcdonalds                          €€             Lewarde          59
# burger_king                         €            Attiches          59
# mc_donalds                    Unknown         Labruguière          81
# mcdonalds                           €             Peyrins          26
# mcdonalds                     Unknown          Hagondange          57
# mcdonalds                          €€        Plénée-Jugon          22
# mc_donalds                    Unknown            Les Ulis          91
# mc_donalds                    Unknown  Clermont-l'Hérault          34
#
#                                 Region
# burger_king                îledefrance
# mcdonalds                hautsdefrance
# mcdonalds                     bretagne
# mc_donalds                   normandie
# snack_109_friterie       hautsdefrance
# mcdonalds           auvergnerhônealpes
# mcdonalds                    grand_est
# upper                nouvelleaquitaine
# mc_donalds          auvergnerhônealpes
# mcdonalds                  îledefrance
# mcdonalds                    occitanie
# mcdonalds                  îledefrance
# mc_donalds           nouvelleaquitaine
# mcdonalds             pays_de_la_loire
# burger_king                  occitanie
# mcdonalds                hautsdefrance
# mcdonalds           centreval_de_loire
# mcdonalds           centreval_de_loire
# mcdonalds                  îledefrance
# mcdonalds                    normandie
# mcdonalds                  îledefrance
# mcdonalds                hautsdefrance
# burger_king              hautsdefrance
# mc_donalds                   occitanie
# mcdonalds           auvergnerhônealpes
# mcdonalds                    grand_est
# mcdonalds                     bretagne
# mc_donalds                 îledefrance
# mc_donalds                   occitanie

# %%
def recommend_region(name, region=None):
    name = name.lower()
    name = name.replace(' ', '_')
    name = name.replace('[^\w\s]','')
    words = name.split()
    # Remove stop words
    filtered_words = [word for word in words if word not in stopwords.words('french')]
    # Join the filtered words back into a sentence
    name = ' '.join(filtered_words)
    indices = pd.Series(df_percent.index)
    cosine_similarities = joblib.load('recommend_name_restaurant.pkl')
    # Create a list to put top restaurants
    recommend_restaurant = []
    
    try:
        # Find the index of the restaurant entered
        idx = indices[indices == name].index[0]
    except:
        print('Restaurant non trouvé')
        return None
    
    # Find the restaurants with a similar cosine-sim value and order them from biggest number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    
    # Filter dataframe by region if specified
    if region:
        df_new = df_percent[df_percent['Region'] == region].copy()
    else:
        df_new = df_percent.copy()
    
    # Create the top 30 similar restaurants with some of their columns
    df_new = df_new[df_new.index.isin(recommend_restaurant)][['Specialite', 'Note moyenne', 'Indicateur de prix','Ville','Departement','Region']]
        
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region'], keep=False)
    df_new = df_new.sort_values(by='Note moyenne', ascending=False)
    
    return df_new

# %%
recommend_region('McDonalds', region='îledefrance')
# Out:
# TOP 35 RESTAURANTS SIMILAIRES A mcdonalds AVEC UNE NOTE PROCHE :
#                                        Specialite  Note moyenne  \
# Nom du restaurant
# burger_king                     fast_food_burgers           5.0
# mc_donalds                      fast_food_burgers           5.0
# mc_donalds                              fast_food           5.0
# mcdonalds                       fast_food_burgers           4.5
# mcdonalds                       fast_food_burgers           4.5
# mcdonalds                       fast_food_burgers           4.5
# mcdonalds                       fast_food_burgers           4.0
# burger_king                               burgers           4.0
# mcdonalds                       burgers_fast_food           4.0
# mcdonalds                       burgers_fast_food           4.0
# mcdonalds                       fast_food_burgers           3.5
# mcdonalds                       burgers_fast_food           3.5
# mcdonalds                       fast_food_burgers           3.5
# mcdonalds                       burgers_fast_food           3.5
# mcdonalds                       fast_food_burgers           3.5
# mcdonalds                       burgers_fast_food           3.5
# mcdonalds                       fast_food_burgers           3.5
# mcdonalds                               fast_food           3.5
# mcdonalds                       burgers_fast_food           3.5
# mcdonalds                       fast_food_burgers           3.0
# mcdonalds                       fast_food_burgers           3.0
# mcdonalds                       fast_food_burgers           3.0
# mcdonalds                       fast_food_burgers           3.0
# mc_donalds                              fast_food           3.0
# mc_donalds                      fast_food_burgers           3.0
# mc_donalds                              fast_food           3.0
# mcdonalds                       fast_food_burgers           3.0
# mcdonalds                       fast_food_burgers           3.0
# mcdonalds                       fast_food_burgers           3.0
# mcdonalds                               fast_food           2.5
# mcdonalds                       fast_food_burgers           2.5
# mcdonalds                       fast_food_burgers           2.5
# mcdonalds                       fast_food_burgers           2.0
# mc_donalds         fast_food_american_traditional           1.5
# mcdonalds                       fast_food_burgers           1.0
#
#                   Indicateur de prix                    Ville Departement  \
# Nom du restaurant
# burger_king                  Unknown       Mézières-sur-Seine          78
# mc_donalds                   Unknown         Gometz-le-Châtel          91
# mc_donalds                         €         Forges-les-Bains          91
# mcdonalds                          €       Fontenay-lès-Briis          91
# mcdonalds                          €        Longpont-sur-Orge          91
# mcdonalds                          €          Ballainvilliers          91
# mcdonalds                         €€                  Groslay          95
# burger_king                  Unknown     Les Clayes-sous-Bois          78
# mcdonalds                    Unknown                 Maurepas          78
# mcdonalds                    Unknown                Auffargis          78
# mcdonalds                    Unknown        Leuville-sur-Orge          91
# mcdonalds                    Unknown                    Issou          78
# mcdonalds                         €€    Le Mesnil-Saint-Denis          78
# mcdonalds                    Unknown                  Juziers          78
# mcdonalds                    Unknown          Le Plessis-Pâté          91
# mcdonalds                    Unknown           Morainvilliers          78
# mcdonalds                    Unknown               Athis-Mons          91
# mcdonalds                          €               Le Chesnay          78
# mcdonalds                    Unknown               Ecquevilly          78
# mcdonalds                    Unknown                   Éragny          95
# mcdonalds                    Unknown                  Plaisir          78
# mcdonalds                         €€                    Ormoy          91
# mcdonalds                         €€                  Mennecy          91
# mc_donalds                   Unknown          Boissise-le-Roi          77
# mc_donalds                         €                   Écouen          95
# mc_donalds                   Unknown           Marly-la-Ville          95
# mcdonalds                        €€€  Les Pavillons-sous-Bois          93
# mcdonalds                         €€         Corbeil-Essonnes          91
# mcdonalds                    Unknown                   Ennery          95
# mcdonalds                    Unknown                   Grigny          91
# mcdonalds                         €€                    Issou          78
# mcdonalds                    Unknown               Chaumontel          95
# mcdonalds                    Unknown     Boussy-Saint-Antoine          91
# mc_donalds                   Unknown                 Les Ulis          91
# mcdonalds                    Unknown           Marly-la-Ville          95
#
#                         Region
# Nom du restaurant
# burger_king        îledefrance
# mc_donalds         îledefrance
# mc_donalds         îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# burger_king        îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mc_donalds         îledefrance
# mc_donalds         îledefrance
# mc_donalds         îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mcdonalds          îledefrance
# mc_donalds         îledefrance
# mcdonalds          îledefrance

# %%
def recommend_departement(name, departement=None):
    name = name.lower()
    name = name.replace(' ', '_')
    name = name.replace('[^\w\s]','')
    words = name.split()
    # Remove stop words
    filtered_words = [word for word in words if word not in stopwords.words('french')]
    # Join the filtered words back into a sentence
    name = ' '.join(filtered_words)
    indices = pd.Series(df_percent.index)
    cosine_similarities = joblib.load('recommend_name_restaurant.pkl')
    # Create a list to put top restaurants
    recommend_restaurant = []
    
    try:
        # Find the index of the restaurant entered
        idx = indices[indices == name].index[0]
    except:
        print('Restaurant non trouvé')
        return None
    
    # Find the restaurants with a similar cosine-sim value and order them from biggest number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    
    # Filter dataframe by department if specified
    if departement is not None:
        df_new = df_percent[df_percent['Departement'] == departement].copy()
    else:
        df_new = df_percent.copy()
    
    # Create the top 30 similar restaurants with some of their columns
    df_new = df_new[df_new.index.isin(recommend_restaurant)][['Specialite', 'Note moyenne', 'Indicateur de prix','Ville','Departement','Region']]
        
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['Specialite','Note moyenne', 'Indicateur de prix','Ville','Departement','Region'], keep=False)
    df_new = df_new.sort_values(by='Note moyenne', ascending=False)
    
    return df_new

# %%
recommend_departement('mcdonalds', departement=78)
# Out:
# TOP 0 RESTAURANTS SIMILAIRES A mcdonalds AVEC UNE NOTE PROCHE DANS LE DEPARTEMENT 78:
# Empty DataFrame
# Columns: [Specialite, Note moyenne, Indicateur de prix, Ville, Departement, Region]
# Index: []

# %%
usr_input = input("type a restaurant name:")

import re
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

#function to find between each word in the name of the restaurant and the name of the restaurant in the database
def find_resto(word):
    for i in df_percent.index:
        # check similarity between the word and the name of the restaurant
        similarity = similar(i, word)
        if similarity > 0.9:
            return i
            
def find_region(word):
    for i in df_percent['Region'].unique():
        # check similarity between the word and the name of the region
        similarity = similar(i, word)
        if similarity > 0.9:
            return i
        
def find_departement(word):
    pattern = r'\d+'
    if re.findall(pattern, word):
        for i in df_percent['Departement'].unique():
            # check similarity between the word and the name of the region
            if word == str(i):
                return i
            
def is_resto(word):
    for i in df_percent.index:
        # check similarity between the word and the name of the restaurant
        similarity = similar(i, word)
        if similarity > 0.9:
            return True
            
    return False
            
def is_region(word):
    for i in df_percent['Region'].unique():
        # check similarity between the word and the name of the region
        similarity = similar(i, word)
        if similarity > 0.9:
            return True

    return False

def is_departement(word):
    pattern = r'\d+'
    if re.findall(pattern, word):
        for i in df_percent['Departement'].unique():
            # check similarity between the word and the name of the region
            if word == str(i):
                return True
            
    return False

def print_resto(df,max=1000000):
    if len(df) == 0:
        return "Je n'ai pas trouvé de restaurant correspondant à votre demande"
    else:
        finalAnswer = str("Voici les restaurants que je vous recommande : \n")
        if len(df) < max:
            for i in range(len(df)):
                resto_string = str(i)+" : " +str('Spécialité : '+df.iloc[i]['Specialite']) + ' - Note (/5)' + str(df.iloc[i]['Note moyenne']) + ' - Prix : ' + str(df.iloc[i]['Indicateur de prix']) + ' - Ville : ' + str(df.iloc[i]['Ville']) + ' - Departement : ' + str(df.iloc[i]['Departement']) + ' - Région : ' + str(df.iloc[i]['Region']) 
                finalAnswer += resto_string + "\n"
        else:
            for i in range(max):
                resto_string = str(i)+" : " +str('Spécialité : '+df.iloc[i]['Specialite']) + ' - Note (/5)' + str(df.iloc[i]['Note moyenne']) + ' - Prix : ' + str(df.iloc[i]['Indicateur de prix']) + ' - Ville : ' + str(df.iloc[i]['Ville']) + ' - Departement : ' + str(df.iloc[i]['Departement']) + ' - Région : ' + str(df.iloc[i]['Region']) 
                finalAnswer += resto_string + "\n"

    return finalAnswer

def word_is_max(word):
    if  "max" in word:
        return True
    else:
        return False


def generate_response(user_input):
    restoFind = None
    regionFind = None
    departementFind = None
    max = 1000000
    for word in user_input.split():
            if word_is_max(word):
                max = int(word[4:])
            if is_resto(word):
                restoFind = find_resto(word)
            if is_region(word):
                regionFind = find_region(word)
            if is_departement(word):
                departementFind = find_departement(word)

            print(restoFind, regionFind, departementFind)

    if restoFind != None:
        if restoFind != None:
            print("region")
            print(print_resto(recommend_region(restoFind, regionFind),max))
        elif departementFind != None:
            print("departement")
            print(print_resto(recommend_departement(restoFind, departementFind),max))
        else:
            print("resto")
            print(print_resto(recommend_restaurant(restoFind),max))
    else:
        print("Je n'ai pas compris votre demande, veuillez réessayer")

generate_response(usr_input)
# Out:
# mcdonalds None None
# mcdonalds None None
# region
# TOP 216 RESTAURANTS SIMILAIRES A mcdonalds AVEC UNE NOTE PROCHE :
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7476\553043206.py in <module>
#     111         print("Je n'ai pas compris votre demande, veuillez réessayer")
#     112
# --> 113 generate_response(usr_input)
#
# ~\AppData\Local\Temp\ipykernel_7476\553043206.py in generate_response(user_input)
#     101         if restoFind != None:
#     102             print("region")
# --> 103             print(print_resto(recommend_region(restoFind, regionFind),max))
#     104         elif departementFind != None:
#     105             print("departement")
#
# ~\AppData\Local\Temp\ipykernel_7476\553043206.py in print_resto(df, max)
#      63     else:
#      64         finalAnswer = str("Voici les restaurants que je vous recommande : \n")
# ---> 65         if len(df) < max:
#      66             for i in range(len(df)):
#      67                 resto_string = str(i)+" : " +str('Spécialité : '+df.iloc[i]['Specialite']) + ' - Note (/5)' + str(df.iloc[i]['Note moyenne']) + ' - Prix : ' + str(df.iloc[i]['Indicateur de prix']) + ' - Ville : ' + str(df.iloc[i]['Ville']) + ' - Departement : ' + str(df.iloc[i]['Departement']) + ' - Région : ' + str(df.iloc[i]['Region'])
#
# TypeError: '<' not supported between instances of 'int' and 'str'
